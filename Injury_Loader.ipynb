# %%
import requests
import pandas as pd
import pdfplumber
import re
from datetime import datetime, timedelta
from typing import List, Dict, Optional, Tuple
import time
import json
import logging
import os

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class NBAInjuryReportScraper:
    def __init__(self, cache_dir: str = "pdf_cache"):
        self.base_url = "https://ak-static.cms.nba.com/referee/injury/Injury-Report_{date}_{time}.pdf"
        self.cache_dir = cache_dir
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        })
        
        os.makedirs(cache_dir, exist_ok=True)
        self.all_data = []
    
    def format_player_name(self, name: str) -> str:
        """Convert 'Last,First' to 'First Last' format"""
        if ',' in name:
            parts = name.split(',')
            if len(parts) == 2:
                last_name = parts[0].strip()
                first_name = parts[1].strip()
                return f"{first_name} {last_name}"
        return name  # Return as-is if not in expected format
    
    def debug_game_info(self, pdf_content: bytes):
        """Helper function to debug game information extraction"""
        try:
            import io
            pdf_file = io.BytesIO(pdf_content)
            with pdfplumber.open(pdf_file) as pdf:
                print("\n=== DEBUGGING GAME INFO EXTRACTION ===\n")
                
                for page_num, page in enumerate(pdf.pages):
                    text = page.extract_text()
                    if text:
                        lines = text.split('\n')
                        print(f"\n--- PAGE {page_num + 1} ---")
                        
                        for line_num, line in enumerate(lines):
                            # Check if line contains date pattern
                            has_date = re.search(r'\d{1,2}/\d{1,2}/\d{4}', line)
                            # Check if line contains time pattern
                            has_time = re.search(r'\d{1,2}:\d{2}', line)
                            # Check if line contains matchup pattern
                            has_matchup = re.search(r'[A-Z]{3}@[A-Z]{3}', line)
                            # Check if line contains "ET"
                            has_et = 'ET' in line
                            
                            # Print lines that have any game-related info
                            if has_date or has_time or has_matchup or (has_et and has_time):
                                print(f"Line {line_num}: {line.strip()}")
                                if has_date:
                                    print(f"  → Date found: {has_date.group()}")
                                if has_time:
                                    print(f"  → Time found: {has_time.group()}")
                                if has_matchup:
                                    print(f"  → Matchup found: {has_matchup.group()}")
                                print()
                
                print("=== END DEBUG ===\n")
                
        except Exception as e:
            print(f"Error in debug: {e}")
            import traceback
            traceback.print_exc()
    
    def download_pdf(self, url: str, date: str, time_slot: str) -> Optional[bytes]:
        cache_filename = f"{self.cache_dir}/injury_report_{date}_{time_slot}.pdf"
        
        if os.path.exists(cache_filename):
            logger.info(f"Loading from cache: {cache_filename}")
            with open(cache_filename, 'rb') as f:
                return f.read()
        
        try:
            logger.info(f"Downloading: {url}")
            response = self.session.get(url, timeout=30)
            
            if response.status_code == 200:
                with open(cache_filename, 'wb') as f:
                    f.write(response.content)
                logger.info(f"Successfully downloaded and cached: {cache_filename}")
                return response.content
            else:
                logger.warning(f"HTTP {response.status_code} for {url}")
                return None
                
        except requests.exceptions.RequestException as e:
            logger.error(f"Error downloading {url}: {e}")
            return None
    
    def parse_2023_format(self, pdf_content: bytes, report_date: str, time_slot: str) -> List[Dict]:
        try:
            import io
            pdf_file = io.BytesIO(pdf_content)
            with pdfplumber.open(pdf_file) as pdf:
                # Get all text and process line by line to find patterns
                full_text = ""
                for page in pdf.pages:
                    text = page.extract_text()
                    if text:
                        full_text += text + "\n"
                
                if not full_text:
                    return []
                
                # Debug: Search for Rice in the entire text
                if "Rice" in full_text:
                    logger.info("Found 'Rice' in PDF text!")
                    # Find all occurrences
                    for idx, line in enumerate(full_text.split('\n')):
                        if "Rice" in line:
                            logger.info(f"Rice found at line {idx}: {repr(line)}")
                else:
                    logger.warning("'Rice' NOT found anywhere in the PDF text!")
                
                # Find all injury patterns in the text using a comprehensive approach
                all_injuries = []
                
                # Split into lines for context
                lines = full_text.split('\n')
                
                # Team mapping
                team_map = {
                    'BostonCeltics': 'Boston Celtics',
                    'IndianaPacers': 'Indiana Pacers',
                    'WashingtonWizards': 'Washington Wizards',
                    'OrlandoMagic': 'Orlando Magic',
                    'MemphisGrizzlies': 'Memphis Grizzlies',
                    'DallasMavericks': 'Dallas Mavericks',
                    'NewYorkKnicks': 'New York Knicks',
                    'TorontoRaptors': 'Toronto Raptors',
                    'Philadelphia76ers': 'Philadelphia 76ers',
                    'SanAntonioSpurs': 'San Antonio Spurs',
                    'NewOrleansPelicans': 'New Orleans Pelicans',
                    'DenverNuggets': 'Denver Nuggets',
                    'PhoenixSuns': 'Phoenix Suns',
                    'GoldenStateWarriors': 'Golden State Warriors',
                    'LAClippers': 'LA Clippers',
                    'MinnesotaTimberwolves': 'Minnesota Timberwolves',
                    'CharlotteHornets': 'Charlotte Hornets',
                    'ClevelandCavaliers': 'Cleveland Cavaliers',
                    'DetroitPistons': 'Detroit Pistons',
                    'BrooklynNets': 'Brooklyn Nets',
                    'AtlantaHawks': 'Atlanta Hawks',
                    'MilwaukeeBucks': 'Milwaukee Bucks',
                    'MiamiHeat': 'Miami Heat',
                    'ChicagoBulls': 'Chicago Bulls',
                    'OklahomaCityThunder': 'Oklahoma City Thunder',
                    'PortlandTrailBlazers': 'Portland Trail Blazers',
                    'UtahJazz': 'Utah Jazz',
                    'SacramentoKings': 'Sacramento Kings',
                    'HoustonRockets': 'Houston Rockets',
                    'LosAngelesLakers': 'Los Angeles Lakers'
                }
                
                # FIXED: Track game information throughout the document
                current_game_date = None
                current_game_time = None
                current_matchup = None
                
                # FIXED: Track the current team throughout the entire document
                current_team = "Unknown Team"
                
                # Now find all player patterns in the entire text
                for line_idx, line in enumerate(lines):
                    # First check if this line contains game information
                    # Pattern 1: Full pattern with date
                    full_game_match = re.search(r'(\d{1,2}/\d{1,2}/\d{4})\s+(\d{1,2}:\d{2}\s*\(ET\))\s+([A-Z]{3}@[A-Z]{3})', line)
                    if full_game_match:
                        current_game_date = full_game_match.group(1)
                        current_game_time = full_game_match.group(2)
                        current_matchup = full_game_match.group(3)
                        logger.info(f"Line {line_idx}: Found full game info: {current_matchup} on {current_game_date} at {current_game_time}")
                    else:
                        # Pattern 2: Time and matchup without date (common for same-day games)
                        time_matchup_match = re.search(r'(\d{1,2}:\d{2}\s*\(ET\))\s+([A-Z]{3}@[A-Z]{3})', line)
                        if time_matchup_match:
                            current_game_time = time_matchup_match.group(1)
                            current_matchup = time_matchup_match.group(2)
                            # Always use report date for games without explicit dates
                            # Convert report date format (2023-12-01) to game date format (12/01/2023)
                            date_parts = report_date.split('-')
                            current_game_date = f"{date_parts[1]}/{date_parts[2]}/{date_parts[0]}"
                            logger.info(f"Line {line_idx}: Found time+matchup: {current_matchup} at {current_game_time} (date: {current_game_date})")
                        else:
                            # Pattern 3: Just matchup (like NYK@TOR)
                            just_matchup_match = re.search(r'([A-Z]{3}@[A-Z]{3})', line)
                            if just_matchup_match:
                                # Only update if this appears to be a new game line
                                # Check if the matchup is at/near the start of the line and followed by a team
                                line_start = line.strip()
                                if line_start.startswith(just_matchup_match.group(1)) or line_start.split()[0] == just_matchup_match.group(1):
                                    for team_key in team_map.keys():
                                        if team_key in line:
                                            current_matchup = just_matchup_match.group(1)
                                            # Keep existing game date/time or use report date if none
                                            if not current_game_date:
                                                date_parts = report_date.split('-')
                                                current_game_date = f"{date_parts[1]}/{date_parts[2]}/{date_parts[0]}"
                                            logger.info(f"Line {line_idx}: Found matchup only: {current_matchup}")
                                            break
                    
                    # Check if this line contains "NOT YET SUBMITTED"
                    if "NOTYETSUBMITTED" in line:
                        # Extract team name from the line
                        for team_key, team_name in team_map.items():
                            if team_key in line:
                                logger.info(f"Found NOT YET SUBMITTED for team: {team_name}")
                                all_injuries.append({
                                    'player_name': "NOT YET SUBMITTED",
                                    'team': team_name,
                                    'status': "NOT YET SUBMITTED",
                                    'reason': "NOT YET SUBMITTED",
                                    'game_date': current_game_date,
                                    'game_time': current_game_time,
                                    'matchup': current_matchup,
                                    'report_date': report_date,
                                    'report_time': time_slot
                                })
                                break
                        continue  # Skip to next line
                    
                    # First check if this line contains a team name
                    for team_key, team_name in team_map.items():
                        if team_key in line:
                            current_team = team_name
                            logger.debug(f"Found team: {current_team} at line {line_idx}")
                            break
                    
                    # Then find players in this line
                    player_matches = re.finditer(r"([A-Za-z\-\.']+,[A-Za-z\-\.']+)\s+(Out|Available|Questionable|Probable|Doubtful)", line)
                    
                    for match in player_matches:
                        player_name_raw = match.group(1)
                        status = match.group(2)
                        
                        # Format the player name from "Last,First" to "First Last"
                        player_name = self.format_player_name(player_name_raw)
                        
                        # Use the current team instead of looking backwards
                        assigned_team = current_team
                        
                        # Get reason from the current line after the status
                        reason_start = match.end()
                        reason = line[reason_start:].strip()
                        
                        # Look for additional injury context in nearby lines
                        context_lines = []
                        for i in range(max(0, line_idx - 3), min(len(lines), line_idx + 4)):
                            if ('Injury/Illness' in lines[i] or 
                                any(term in lines[i].lower() for term in ['contusion', 'sprain', 'strain', 'fracture', 'infection', 'bruise', 'respiratory', 'bone', 'meniscus'])):
                                context_lines.append(lines[i].strip())
                        
                        # Combine context with reason
                        if context_lines and not reason:
                            reason = ' '.join(context_lines)
                        elif context_lines:
                            reason = ' '.join(context_lines) + ' ' + reason
                        
                        all_injuries.append({
                            'player_name': player_name,
                            'team': assigned_team,
                            'status': status,
                            'reason': reason.strip(),
                            'game_date': current_game_date,
                            'game_time': current_game_time,
                            'matchup': current_matchup,
                            'report_date': report_date,
                            'report_time': time_slot
                        })
                        
                        logger.info(f"Found: {player_name} ({assigned_team}) - {status}: {reason}")
                
                # Return all injuries as a single list wrapped in a game structure
                # This maintains compatibility with the existing export format
                if all_injuries:
                    # We'll use a dummy game structure since injuries already contain game info
                    game = {
                        'game_date': 'Multiple',
                        'game_time': 'Multiple',
                        'matchup': 'Multiple',
                        'report_date': report_date,
                        'report_time': time_slot,
                        'injuries': all_injuries
                    }
                    return [game]
                
                return []
                
        except Exception as e:
            logger.error(f"Error parsing PDF: {e}")
            import traceback
            logger.error(traceback.format_exc())
            return []
    
    def scrape_date(self, date: str) -> List[Dict]:
        """Scrape a single date"""
        for time_slot in ["05PM", "08PM"]:
            url = self.base_url.format(date=date, time=time_slot)
            pdf_content = self.download_pdf(url, date, time_slot)
            
            if pdf_content:
                year = int(date.split('-')[0])
                if year >= 2023:
                    games = self.parse_2023_format(pdf_content, date, time_slot)
                    if games:
                        return games
        
        return []
    
    def scrape_date_range(self, start_date: str, end_date: str):
        """Scrape a date range"""
        start = datetime.strptime(start_date, "%Y-%m-%d")
        end = datetime.strptime(end_date, "%Y-%m-%d")
        
        current = start
        while current <= end:
            date_str = current.strftime("%Y-%m-%d")
            games = self.scrape_date(date_str)
            self.all_data.extend(games)
            current += timedelta(days=1)
    
    def export_to_csv(self, filename: str):
        if not self.all_data:
            logger.warning("No data to export")
            return
        
        # Flatten the data for CSV export
        flattened_data = []
        
        for game in self.all_data:
            for injury in game.get('injuries', []):
                row = {
                    'report_date': game.get('report_date'),
                    'report_time': game.get('report_time'),
                    'game_date': injury.get('game_date'),  # Use injury's game info
                    'game_time': injury.get('game_time'),  # Use injury's game info
                    'matchup': injury.get('matchup'),      # Use injury's game info
                    'player_name': injury.get('player_name'),
                    'team': injury.get('team'),
                    'status': injury.get('status')
                    # Removed 'reason' column as requested
                }
                flattened_data.append(row)
        
        df = pd.DataFrame(flattened_data)
        df.to_csv(filename, index=False)
        logger.info(f"Exported {len(flattened_data)} injury records to {filename}")

# Usage
if __name__ == "__main__":
    scraper = NBAInjuryReportScraper()
    
    # Test the specific URL you provided
    print("=== Testing 2023-12-01 08PM ===")
    pdf_content = scraper.download_pdf(
        "https://ak-static.cms.nba.com/referee/injury/Injury-Report_2023-12-01_08PM.pdf",
        "2023-12-01", "08PM"
    )
    
    if pdf_content:
        # First, debug to see game info structure
        scraper.debug_game_info(pdf_content)
        
        # Then run normal parsing
        games = scraper.parse_2023_format(pdf_content, "2023-12-01", "08PM")
        
        if games:
            for game in games:
                print(f"\nGame: {game['game_date']} {game['matchup']}")
                print(f"Injuries found: {len(game['injuries'])}")
                
                # Group by team
                by_team = {}
                for injury in game['injuries']:
                    team = injury['team']
                    if team not in by_team:
                        by_team[team] = []
                    by_team[team].append(injury)
                
                for team, injuries in by_team.items():
                    print(f"\n  {team}:")
                    for injury in injuries:
                        print(f"    - {injury['player_name']} - {injury['status']}: {injury['reason'][:100]}...")
        else:
            print("No games found")
    else:
        print("Failed to download PDF")
    
    # Also test the original date for comparison
    print("\n" + "="*50)
    print("=== Testing 2023-12-03 05PM (original) ===")
    games_original = scraper.scrape_date("2023-12-03")
    
    if games_original:
        for game in games_original:
            print(f"\nGame: {game['game_date']} {game['matchup']}")
            print(f"Injuries found: {len(game['injuries'])}")
            
            # Just list player names for quick comparison
            players = [injury['player_name'] for injury in game['injuries']]
            print(f"Players: {', '.join(players)}")
    
    # Export both if we have data
    all_games = []
    if games:
        all_games.extend(games)
    if games_original:
        all_games.extend(games_original)
    
    if all_games:
        scraper.all_data = all_games
        scraper.export_to_csv("nba_injuries_test.csv")
        print(f"\nExported {sum(len(g['injuries']) for g in all_games)} total injuries to CSV")
# Out:
# 2025-07-25 10:55:28,798 - INFO - Loading from cache: pdf_cache/injury_report_2023-12-01_08PM.pdf
# === Testing 2023-12-01 08PM ===
#
# === DEBUGGING GAME INFO EXTRACTION ===
#
#
# --- PAGE 1 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 3: 12/01/2023 07:00(ET) WAS@ORL WashingtonWizards Rollins,Ryan Out
#   → Date found: 12/01/2023
#   → Time found: 07:00
#   → Matchup found: WAS@ORL
#
# Line 18: 07:30(ET) MEM@DAL MemphisGrizzlies Adams,Steven Out
#   → Time found: 07:30
#   → Matchup found: MEM@DAL
#
#
# --- PAGE 2 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 14: NYK@TOR NewYorkKnicks BrownJr.,Charlie Out GLeague-Two-Way
#   → Matchup found: NYK@TOR
#
#
# --- PAGE 3 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 3: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness
#   → Matchup found: PHI@BOS
#
# Line 16: 08:00(ET) SAS@NOP SanAntonioSpurs Bediako,Charles Out GLeague-Two-Way
#   → Time found: 08:00
#   → Matchup found: SAS@NOP
#
#
# --- PAGE 4 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 9: 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery
#   → Time found: 10:00
#   → Matchup found: DEN@PHX
#
# Line 22: 12/02/2023 04:00(ET) GSW@LAC GoldenStateWarriors Garuba,Usman Out
#   → Date found: 12/02/2023
#   → Time found: 04:00
#   → Matchup found: GSW@LAC
#
#
# --- PAGE 5 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 9: 05:00(ET) MIN@CHA MinnesotaTimberwolves Clark,Jaylen Out
#   → Time found: 05:00
#   → Matchup found: MIN@CHA
#
# Line 25: 07:00(ET) CLE@DET ClevelandCavaliers Bates,Emoni Out GLeague-Two-Way
#   → Time found: 07:00
#   → Matchup found: CLE@DET
#
#
# --- PAGE 6 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 16: ORL@BKN OrlandoMagic NOTYETSUBMITTED
#   → Matchup found: ORL@BKN
#
#
# --- PAGE 7 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 6: 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture
#   → Time found: 08:00
#   → Matchup found: ATL@MIL
#
# Line 21: IND@MIA IndianaPacers Brown,Kendall Questionable GLeague-Two-Way
#   → Matchup found: IND@MIA
#
#
# --- PAGE 8 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 13: NOP@CHI NewOrleansPelicans NOTYETSUBMITTED
#   → Matchup found: NOP@CHI
#
# Line 20: 09:00(ET) MEM@PHX MemphisGrizzlies NOTYETSUBMITTED
#   → Time found: 09:00
#   → Matchup found: MEM@PHX
#
#
# --- PAGE 9 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 1: OKC@DAL OklahomaCityThunder Dieng,Ousmane Out GLeague-OnAssignment
#   → Matchup found: OKC@DAL
#
# Line 4: 09:30(ET) POR@UTA PortlandTrailBlazers Badji,Ibou Questionable GLeague-Two-Way
#   → Time found: 09:30
#   → Matchup found: POR@UTA
#
#
# --- PAGE 10 ---
# Line 0: Injury Report: 12/01/23 08:30 PM
#   → Time found: 08:30
#
# Line 1: 10:00(ET) DEN@SAC DenverNuggets NOTYETSUBMITTED
#   → Time found: 10:00
#   → Matchup found: DEN@SAC
#
# Line 8: 10:30(ET) HOU@LAL HoustonRockets Oladipo,Victor Out
#   → Time found: 10:30
#   → Matchup found: HOU@LAL
#
# === END DEBUG ===
# 2025-07-25 10:55:29,103 - INFO - Found 'Rice' in PDF text!
# 2025-07-25 10:55:29,104 - INFO - Rice found at line 73: "Rice,Sir'Jabari Out GLeague-Two-Way"
# 2025-07-25 10:55:29,104 - INFO - Line 3: Found full game info: WAS@ORL on 12/01/2023 at 07:00(ET)
# 2025-07-25 10:55:29,104 - INFO - Found: Ryan Rollins (Washington Wizards) - Out: Injury/Illness-RightKnee;Rightknee strain Injury/Illness-LeftKnee;Leftknee
# 2025-07-25 10:55:29,105 - INFO - Found: Delon Wright (Washington Wizards) - Out: strain Injury/Illness-LeftKnee;Leftknee sprain OrlandoMagic Banchero,Paolo Available Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftHand;Fractured
# 2025-07-25 10:55:29,105 - INFO - Found: Paolo Banchero (Orlando Magic) - Available: Injury/Illness-LeftKnee;Leftknee sprain OrlandoMagic Banchero,Paolo Available Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftHand;Fractured Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,105 - INFO - Found: Wendell CarterJr. (Orlando Magic) - Out: sprain OrlandoMagic Banchero,Paolo Available Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftHand;Fractured Fultz,Markelle Out Injury/Illness-LeftKnee;Tendinitis
# 2025-07-25 10:55:29,105 - INFO - Found: Markelle Fultz (Orlando Magic) - Out: Injury/Illness-LeftHand;Fractured Fultz,Markelle Out Injury/Illness-LeftKnee;Tendinitis Howard,Jett Available Injury/Illness-LeftAnkle;Sprain Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Tendinitis
# 2025-07-25 10:55:29,105 - INFO - Found: Kevon Harris (Orlando Magic) - Out: Fultz,Markelle Out Injury/Illness-LeftKnee;Tendinitis Howard,Jett Available Injury/Illness-LeftAnkle;Sprain Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Coach'sDecision
# 2025-07-25 10:55:29,105 - INFO - Found: Jett Howard (Orlando Magic) - Available: Fultz,Markelle Out Injury/Illness-LeftKnee;Tendinitis Howard,Jett Available Injury/Illness-LeftAnkle;Sprain Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee;PCL Injury/Illness-LeftAnkle;Sprain
# 2025-07-25 10:55:29,106 - INFO - Found: Jonathan Isaac (Orlando Magic) - Available: Fultz,Markelle Out Injury/Illness-LeftKnee;Tendinitis Howard,Jett Available Injury/Illness-LeftAnkle;Sprain Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee;PCL Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,106 - INFO - Found: Trevelin Queen (Orlando Magic) - Out: Howard,Jett Available Injury/Illness-LeftAnkle;Sprain Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee;PCL GLeague-Two-Way
# 2025-07-25 10:55:29,106 - INFO - Line 18: Found time+matchup: MEM@DAL at 07:30(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,106 - INFO - Found: Steven Adams (Memphis Grizzlies) - Out: Isaac,Jonathan Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee;PCL Injury/Illness-LeftAchilles;Tendon
# 2025-07-25 10:55:29,106 - INFO - Found: Brandon Clarke (Memphis Grizzlies) - Out: Injury/Illness-LeftAchilles;Tendon Kennard,Luke Out Injury/Illness-LeftKnee;BoneBruise
# 2025-07-25 10:55:29,106 - INFO - Found: GG Jackson (Memphis Grizzlies) - Out: Injury/Illness-LeftAchilles;Tendon Kennard,Luke Out Injury/Illness-LeftKnee;BoneBruise LaRavia,Jake Out Injury/Illness-LeftEye;Procedure GLeague-Two-Way
# 2025-07-25 10:55:29,107 - INFO - Found: Luke Kennard (Memphis Grizzlies) - Out: Kennard,Luke Out Injury/Illness-LeftKnee;BoneBruise LaRavia,Jake Out Injury/Illness-LeftEye;Procedure Injury/Illness-LeftKnee;BoneBruise
# 2025-07-25 10:55:29,107 - INFO - Found: Jake LaRavia (Memphis Grizzlies) - Out: Kennard,Luke Out Injury/Illness-LeftKnee;BoneBruise LaRavia,Jake Out Injury/Illness-LeftEye;Procedure Injury/Illness-LeftEye;Procedure
# 2025-07-25 10:55:29,107 - INFO - Found: Ja Morant (Memphis Grizzlies) - Out: LaRavia,Jake Out Injury/Illness-LeftEye;Procedure Smart,Marcus Out Injury/Illness-LeftFoot;Sprain Injury/Illness-LeftKnee;Injury LeagueSuspension
# 2025-07-25 10:55:29,107 - INFO - Found: Marcus Smart (Memphis Grizzlies) - Out: Smart,Marcus Out Injury/Illness-LeftFoot;Sprain Injury/Illness-LeftKnee;Injury Injury/Illness-LeftFoot;Sprain
# 2025-07-25 10:55:29,107 - INFO - Found: Xavier Tillman (Memphis Grizzlies) - Available: Smart,Marcus Out Injury/Illness-LeftFoot;Sprain Injury/Illness-LeftKnee;Injury
# 2025-07-25 10:55:29,107 - INFO - Found: Greg BrownIII (Dallas Mavericks) - Out: Injury/Illness-LeftKnee;Injury HardawayJr.,Tim Out Injury/Illness-Back;Spasms GLeague-Two-Way
# 2025-07-25 10:55:29,108 - INFO - Found: Luka Doncic (Dallas Mavericks) - Out: HardawayJr.,Tim Out Injury/Illness-Back;Spasms Injury/Illness-RightSmallToe; PersonalReasons
# 2025-07-25 10:55:29,108 - INFO - Found: Dante Exum (Dallas Mavericks) - Out: HardawayJr.,Tim Out Injury/Illness-Back;Spasms Injury/Illness-RightSmallToe; PersonalReasons
# 2025-07-25 10:55:29,108 - INFO - Found: Tim HardawayJr. (Dallas Mavericks) - Out: HardawayJr.,Tim Out Injury/Illness-Back;Spasms Injury/Illness-RightSmallToe; Injury/Illness-Back;Spasms
# 2025-07-25 10:55:29,108 - INFO - Found: Maxi Kleber (Dallas Mavericks) - Out: HardawayJr.,Tim Out Injury/Illness-Back;Spasms Injury/Illness-RightSmallToe; Prosper,Olivier-Maxence Available Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,108 - INFO - Found: Olivier-Maxence Prosper (Dallas Mavericks) - Available: Injury/Illness-RightSmallToe; Prosper,Olivier-Maxence Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee; Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,108 - INFO - Line 41: Found matchup only: NYK@TOR
# 2025-07-25 10:55:29,109 - INFO - Found: Charlie BrownJr. (New York Knicks) - Out: Prosper,Olivier-Maxence Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee; GLeague-Two-Way
# 2025-07-25 10:55:29,109 - INFO - Found: Jaylen Martin (New York Knicks) - Out: Prosper,Olivier-Maxence Available Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKnee; GLeague-Two-Way
# 2025-07-25 10:55:29,109 - INFO - Found: Julius Randle (New York Knicks) - Available: Injury/Illness-RightKnee;
# 2025-07-25 10:55:29,109 - INFO - Found: Jacob Toppin (New York Knicks) - Out: Injury/Illness-RightKnee; TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness GLeague-Two-Way
# 2025-07-25 10:55:29,109 - INFO - Found: Dylan Windler (New York Knicks) - Out: TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness GLeague-OnAssignment
# 2025-07-25 10:55:29,109 - INFO - Found: Gradey Dick (Toronto Raptors) - Out: TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness Koloko,Christian Out Injury/Illness-Illness;Respiratory Injury/Illness-Illness;Illness
# 2025-07-25 10:55:29,109 - INFO - Found: Javon Freeman-Liberty (Toronto Raptors) - Out: TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness Koloko,Christian Out Injury/Illness-Illness;Respiratory GLeague-Two-Way
# 2025-07-25 10:55:29,110 - INFO - Found: Ron HarperJr. (Toronto Raptors) - Out: TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness Koloko,Christian Out Injury/Illness-Illness;Respiratory GLeague-Two-Way
# 2025-07-25 10:55:29,110 - INFO - Found: Christian Koloko (Toronto Raptors) - Out: TorontoRaptors Dick,Gradey Out Injury/Illness-Illness;Illness Koloko,Christian Out Injury/Illness-Illness;Respiratory Injury/Illness-Illness;Respiratory
# 2025-07-25 10:55:29,110 - INFO - Found: Markquis Nowell (Toronto Raptors) - Out: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness Embiid,Joel Out Injury/Illness-N/a;Illness GLeague-Two-Way
# 2025-07-25 10:55:29,110 - INFO - Line 56: Found matchup only: PHI@BOS
# 2025-07-25 10:55:29,110 - INFO - Found: Nicolas Batum (Philadelphia 76ers) - Out: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Injury/Illness-RightFinger;Soreness
# 2025-07-25 10:55:29,110 - INFO - Found: Ricky CouncilIV (Philadelphia 76ers) - Out: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness GLeague-Two-Way
# 2025-07-25 10:55:29,110 - INFO - Found: Joel Embiid (Philadelphia 76ers) - Out: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Injury/Illness-N/a;Illness
# 2025-07-25 10:55:29,111 - INFO - Found: Danuel HouseJr. (Philadelphia 76ers) - Out: PHI@BOS Philadelphia76ers Batum,Nicolas Out Injury/Illness-RightFinger;Soreness Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Injury/Illness-LeftQuad;Contusion
# 2025-07-25 10:55:29,111 - INFO - Found: Tyrese Maxey (Philadelphia 76ers) - Out: Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Injury/Illness-N/a;Illness
# 2025-07-25 10:55:29,111 - INFO - Found: Kelly OubreJr. (Philadelphia 76ers) - Out: Embiid,Joel Out Injury/Illness-N/a;Illness HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Springer,Jaden Available Injury/Illness-N/a;Illness Injury/Illness-N/a;RibSoreness
# 2025-07-25 10:55:29,111 - INFO - Found: Javonte Smart (Philadelphia 76ers) - Out: HouseJr.,Danuel Out Injury/Illness-LeftQuad;Contusion Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Springer,Jaden Available Injury/Illness-N/a;Illness NotWithTeam
# 2025-07-25 10:55:29,111 - INFO - Found: Terquavion Smith (Philadelphia 76ers) - Out: Maxey,Tyrese Out Injury/Illness-N/a;Illness OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Springer,Jaden Available Injury/Illness-N/a;Illness GLeague-Two-Way
# 2025-07-25 10:55:29,111 - INFO - Found: Jaden Springer (Philadelphia 76ers) - Available: OubreJr.,Kelly Out Injury/Illness-N/a;RibSoreness Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Injury/Illness-N/a;Illness
# 2025-07-25 10:55:29,111 - INFO - Found: JD Davison (Boston Celtics) - Out: Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,112 - INFO - Found: Nathan Knight (Boston Celtics) - Out: Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,112 - INFO - Found: Kristaps Porzingis (Boston Celtics) - Out: Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Injury/Illness-LeftCalf;Strain
# 2025-07-25 10:55:29,112 - INFO - Found: Jordan Walsh (Boston Celtics) - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightHip;Tightness GLeague-OnAssignment
# 2025-07-25 10:55:29,112 - INFO - Line 69: Found time+matchup: SAS@NOP at 08:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,112 - INFO - Found: Charles Bediako (San Antonio Spurs) - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illness GLeague-Two-Way
# 2025-07-25 10:55:29,112 - INFO - Found: Sidy Cissoko (San Antonio Spurs) - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illness GLeague-OnAssignment
# 2025-07-25 10:55:29,112 - INFO - Found: Keldon Johnson (San Antonio Spurs) - Available: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illness Injury/Illness-RightHip;Tightness
# 2025-07-25 10:55:29,113 - INFO - Found: Doug McDermott (San Antonio Spurs) - Out: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illness Injury/Illness-“”;Illness
# 2025-07-25 10:55:29,113 - INFO - Found: Sir'Jabari Rice (San Antonio Spurs) - Out: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illness Wembanyama,Victor Out Injury/Illness-RightHip;Tightness GLeague-Two-Way
# 2025-07-25 10:55:29,113 - INFO - Found: Victor Wembanyama (San Antonio Spurs) - Out: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Partial Injury/Illness-RightHip;Tightness
# 2025-07-25 10:55:29,114 - INFO - Found: Jose Alvarado (New Orleans Pelicans) - Out: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Partial Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,114 - INFO - Found: Trey MurphyIII (New Orleans Pelicans) - Available: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Partial NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain
# 2025-07-25 10:55:29,114 - INFO - Found: Larry NanceJr. (New Orleans Pelicans) - Out: Injury/Illness-LeftKnee;Partial NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Injury/Illness-RightRib;Fracture
# 2025-07-25 10:55:29,114 - INFO - Found: Matt Ryan (New Orleans Pelicans) - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Injury/Illness-RightCalf;Strain
# 2025-07-25 10:55:29,114 - INFO - Found: Dereon Seabron (New Orleans Pelicans) - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,114 - INFO - Line 84: Found time+matchup: DEN@PHX at 10:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,114 - INFO - Found: Vlatko Cancar (Denver Nuggets) - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Surgery
# 2025-07-25 10:55:29,114 - INFO - Found: Aaron Gordon (Denver Nuggets) - Questionable: Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Injury/Illness-RightHeel;Strain
# 2025-07-25 10:55:29,115 - INFO - Found: Jay Huff (Denver Nuggets) - Out: 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain GLeague-Two-Way
# 2025-07-25 10:55:29,115 - INFO - Found: Jamal Murray (Denver Nuggets) - Questionable: 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Illness;Illness Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,115 - INFO - Found: Jalen Pickett (Denver Nuggets) - Out: Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain GLeague-OnAssignment
# 2025-07-25 10:55:29,115 - INFO - Found: Hunter Tyson (Denver Nuggets) - Out: Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkle;Sprain GLeague-OnAssignment
# 2025-07-25 10:55:29,115 - INFO - Found: Peyton Watson (Denver Nuggets) - Probable: Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkle;Sprain Injury/Illness-RightMeniscus; Injury/Illness-Illness;Illness
# 2025-07-25 10:55:29,115 - INFO - Found: Bradley Beal (Phoenix Suns) - Out: Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkle;Sprain Injury/Illness-RightMeniscus; Injury/Illness-LowBack;Strain
# 2025-07-25 10:55:29,116 - INFO - Found: Devin Booker (Phoenix Suns) - Out: Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkle;Sprain Injury/Illness-RightMeniscus; Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,116 - INFO - Found: Damion Lee (Phoenix Suns) - Out: PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkle;Sprain Injury/Illness-RightMeniscus; Injury/Illness-RightFinger;
# 2025-07-25 10:55:29,116 - INFO - Line 97: Found full game info: GSW@LAC on 12/02/2023 at 04:00(ET)
# 2025-07-25 10:55:29,116 - INFO - Found: Usman Garuba (Golden State Warriors) - Out: Injury/Illness-RightFinger; Paul,Chris Out Injury/Illness-LeftLowerLegNerve;
# 2025-07-25 10:55:29,116 - INFO - Found: Chris Paul (Golden State Warriors) - Out: Injury/Illness-RightFinger; Paul,Chris Out Injury/Illness-LeftLowerLegNerve; Contusion Injury/Illness-LeftLowerLegNerve;
# 2025-07-25 10:55:29,117 - INFO - Found: Gary PaytonII (Golden State Warriors) - Out: Contusion PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illness-RightFinger;Soreness Injury/Illness-LeftQuadriceps; Injury/Illness-RightCalf;Strain
# 2025-07-25 10:55:29,117 - INFO - Found: Andrew Wiggins (Golden State Warriors) - Questionable: Contusion PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illness-RightFinger;Soreness Injury/Illness-LeftQuadriceps; Injury/Illness-RightFinger;Soreness
# 2025-07-25 10:55:29,117 - INFO - Found: Brandon BostonJr. (LA Clippers) - Out: PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illness-RightFinger;Soreness Injury/Illness-LeftQuadriceps; Plumlee,Mason Out Injury/Illness-LeftMCL;Sprain Injury/Illness-RightAchillesTendon;
# 2025-07-25 10:55:29,117 - INFO - Found: Mason Plumlee (LA Clippers) - Out: Injury/Illness-LeftQuadriceps; Plumlee,Mason Out Injury/Illness-LeftMCL;Sprain Injury/Illness-RightAchillesTendon; Injury/Illness-LeftMCL;Sprain
# 2025-07-25 10:55:29,118 - INFO - Line 110: Found time+matchup: MIN@CHA at 05:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,118 - INFO - Found: Jaylen Clark (Minnesota Timberwolves) - Out: Plumlee,Mason Out Injury/Illness-LeftMCL;Sprain Injury/Illness-RightAchillesTendon; Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,119 - INFO - Found: Anthony Edwards (Minnesota Timberwolves) - Doubtful: Injury/Illness-RightAchillesTendon; Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Injury/Illness-RightHip;Pointer
# 2025-07-25 10:55:29,119 - INFO - Found: Jaden McDaniels (Minnesota Timberwolves) - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,120 - INFO - Found: Jordan McLaughlin (Minnesota Timberwolves) - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-RightKneeMcl;Sprain
# 2025-07-25 10:55:29,120 - INFO - Found: Leonard Miller (Minnesota Timberwolves) - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury GLeague-OnAssignment
# 2025-07-25 10:55:29,120 - INFO - Found: Amari Bailey (Charlotte Hornets) - Out: McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury GLeague-Two-Way
# 2025-07-25 10:55:29,121 - INFO - Found: LaMelo Ball (Charlotte Hornets) - Out: McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,121 - INFO - Found: Cody Martin (Charlotte Hornets) - Out: Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury Miller,Brandon Questionable Injury/Illness-LeftAnkle;Sprain Injury/Illness-LeftTibia;Non-
# 2025-07-25 10:55:29,121 - INFO - Found: Brandon Miller (Charlotte Hornets) - Questionable: Injury/Illness-LeftKnee;Injury Miller,Brandon Questionable Injury/Illness-LeftAnkle;Sprain Injury/Illness-LeftTibia;Non- displacedfracture Injury/Illness-LeftAnkle;Sprain
# 2025-07-25 10:55:29,122 - INFO - Found: Frank Ntilikina (Charlotte Hornets) - Out: Miller,Brandon Questionable Injury/Illness-LeftAnkle;Sprain Injury/Illness-LeftTibia;Non- displacedfracture
# 2025-07-25 10:55:29,122 - INFO - Found: Nick Richards (Charlotte Hornets) - Questionable: Injury/Illness-LeftTibia;Non- displacedfracture ConcussionProtocol
# 2025-07-25 10:55:29,122 - INFO - Line 126: Found time+matchup: CLE@DET at 07:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,123 - INFO - Found: Emoni Bates (Cleveland Cavaliers) - Out: displacedfracture Jerome,Ty Out Injury/Illness-RightAnkle;Sprain GLeague-Two-Way
# 2025-07-25 10:55:29,123 - INFO - Found: Ty Jerome (Cleveland Cavaliers) - Out: Jerome,Ty Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,124 - INFO - Found: Caris LeVert (Cleveland Cavaliers) - Out: Jerome,Ty Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury
# 2025-07-25 10:55:29,124 - INFO - Found: Isaiah Mobley (Cleveland Cavaliers) - Out: Injury/Illness-LeftKnee;Injury Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,124 - INFO - Found: Ricky Rubio (Cleveland Cavaliers) - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain NotWithTeam
# 2025-07-25 10:55:29,125 - INFO - Found: Dean Wade (Cleveland Cavaliers) - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,125 - INFO - Found: Bojan Bogdanovic (Detroit Pistons) - Probable: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightQuadriceps; Injury/Illness-RightCalf;Strain
# 2025-07-25 10:55:29,125 - INFO - Found: Malcolm Cazalon (Detroit Pistons) - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightQuadriceps; GLeague-Two-Way
# 2025-07-25 10:55:29,126 - INFO - Found: Joe Harris (Detroit Pistons) - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illness-RightCalf;Strain Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightQuadriceps; Strain Injury/Illness-RightShoulder;Sprain
# 2025-07-25 10:55:29,126 - INFO - Found: Monte Morris (Detroit Pistons) - Out: Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightQuadriceps; Strain Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture
# 2025-07-25 10:55:29,127 - INFO - Found: Jared Rhoden (Detroit Pistons) - Out: Injury/Illness-RightQuadriceps; Strain Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture GLeague-Two-Way
# 2025-07-25 10:55:29,127 - INFO - Found: Ausar Thompson (Detroit Pistons) - Probable: Strain Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture Injury/Illness-RightShoulder; Injury/Illness-RightFacial;Fracture
# 2025-07-25 10:55:29,128 - INFO - Line 144: Found matchup only: ORL@BKN
# 2025-07-25 10:55:29,128 - INFO - Found NOT YET SUBMITTED for team: Orlando Magic
# 2025-07-25 10:55:29,129 - INFO - Found: Armoni Brooks (Brooklyn Nets) - Out: Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture Injury/Illness-RightShoulder; GLeague-Two-Way
# 2025-07-25 10:55:29,129 - INFO - Found: Noah Clowney (Brooklyn Nets) - Out: Injury/Illness-RightShoulder; Injury/Illness-LeftLowerBack;
# 2025-07-25 10:55:29,129 - INFO - Found: Keon Johnson (Brooklyn Nets) - Out: Injury/Illness-RightShoulder; Injury/Illness-LeftLowerBack; GLeague-Two-Way
# 2025-07-25 10:55:29,130 - INFO - Found: Ben Simmons (Brooklyn Nets) - Out: Injury/Illness-LeftLowerBack; SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain
# 2025-07-25 10:55:29,130 - INFO - Found: Dennis SmithJr. (Brooklyn Nets) - Probable: Injury/Illness-LeftLowerBack; SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain WalkerIV,Lonnie Out Injury/Illness-LeftHamstring;Strain Injury/Illness-LowerBack;Strain
# 2025-07-25 10:55:29,130 - INFO - Found: Lonnie WalkerIV (Brooklyn Nets) - Out: SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain WalkerIV,Lonnie Out Injury/Illness-LeftHamstring;Strain Injury/Illness-RightFoot;Injury Injury/Illness-LeftHamstring;Strain
# 2025-07-25 10:55:29,131 - INFO - Found: Dariq Whitehead (Brooklyn Nets) - Out: WalkerIV,Lonnie Out Injury/Illness-LeftHamstring;Strain Injury/Illness-RightFoot;Injury 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture
# 2025-07-25 10:55:29,131 - INFO - Found: Jalen Wilson (Brooklyn Nets) - Out: Injury/Illness-RightFoot;Injury 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture Injury/Illness-RightLowBack;Stress GLeague-Two-Way
# 2025-07-25 10:55:29,131 - INFO - Line 161: Found time+matchup: ATL@MIL at 08:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,132 - INFO - Found: Kobe Bufkin (Atlanta Hawks) - Out: 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture Injury/Illness-RightLowBack;Stress Fracture Injury/Illness-LeftThunb;Fracture
# 2025-07-25 10:55:29,132 - INFO - Found: Mouhamed Gueye (Atlanta Hawks) - Out: 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture Injury/Illness-RightLowBack;Stress Fracture Injury/Illness-LeftDistalRadius;
# 2025-07-25 10:55:29,132 - INFO - Found: Jalen Johnson (Atlanta Hawks) - Out: Fracture Injury/Illness-LeftDistalRadius; Fracture
# 2025-07-25 10:55:29,132 - INFO - Found: Seth Lundy (Atlanta Hawks) - Out: Injury/Illness-LeftDistalRadius; Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain GLeague-Two-Way
# 2025-07-25 10:55:29,132 - INFO - Found: Miles Norris (Atlanta Hawks) - Out: Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery GLeague-Two-Way
# 2025-07-25 10:55:29,132 - INFO - Found: Marques Bolden (Milwaukee Bucks) - Available: Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms GLeague-Two-Way
# 2025-07-25 10:55:29,133 - INFO - Found: Pat Connaughton (Milwaukee Bucks) - Out: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,133 - INFO - Found: Jae Crowder (Milwaukee Bucks) - Out: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Injury/Illness-LeftAdductor;Surgery
# 2025-07-25 10:55:29,133 - INFO - Found: Andre JacksonJr. (Milwaukee Bucks) - Questionable: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Injury/Illness-LowerBack;Spasms
# 2025-07-25 10:55:29,133 - INFO - Found: TyTy WashingtonJr. (Milwaukee Bucks) - Available: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise GLeague-Two-Way
# 2025-07-25 10:55:29,133 - INFO - Found: Lindell Wigginton (Milwaukee Bucks) - Available: Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left GLeague-Two-Way
# 2025-07-25 10:55:29,133 - INFO - Line 176: Found matchup only: IND@MIA
# 2025-07-25 10:55:29,133 - INFO - Found: Kendall Brown (Indiana Pacers) - Questionable: JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left GLeague-Two-Way
# 2025-07-25 10:55:29,134 - INFO - Found: Tyrese Haliburton (Indiana Pacers) - Questionable: Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left KneeBoneBruise,LeftHeel Injury/Illness-RightKnee;Bruise
# 2025-07-25 10:55:29,134 - INFO - Found: Jalen Smith (Indiana Pacers) - Out: Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left KneeBoneBruise,LeftHeel
# 2025-07-25 10:55:29,134 - INFO - Found: Oscar Tshiebwe (Indiana Pacers) - Questionable: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain GLeague-Two-Way
# 2025-07-25 10:55:29,134 - INFO - Found: Isaiah Wong (Indiana Pacers) - Questionable: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain GLeague-Two-Way
# 2025-07-25 10:55:29,134 - INFO - Found: Bam Adebayo (Miami Heat) - Out: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftHip;Contusion
# 2025-07-25 10:55:29,134 - INFO - Found: Jimmy Butler (Miami Heat) - Probable: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,134 - INFO - Found: R.J. Hampton (Miami Heat) - Out: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illness-RightThumb;Sprain Injury/Illness-RightKnee;Sprain
# 2025-07-25 10:55:29,135 - INFO - Found: Tyler Herro (Miami Heat) - Out: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illness-RightThumb;Sprain Injury/Illness-RightKnee;ACL3rd Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,135 - INFO - Found: Haywood Highsmith (Miami Heat) - Available: Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illness-RightThumb;Sprain Injury/Illness-RightKnee;ACL3rd Injury/Illness-LowerBack;Contusion
# 2025-07-25 10:55:29,135 - INFO - Found: Duncan Robinson (Miami Heat) - Available: Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illness-RightThumb;Sprain Injury/Illness-RightKnee;ACL3rd DegreeSprain Injury/Illness-RightThumb;Sprain
# 2025-07-25 10:55:29,135 - INFO - Found: Dru Smith (Miami Heat) - Out: Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illness-RightThumb;Sprain Injury/Illness-RightKnee;ACL3rd DegreeSprain ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery
# 2025-07-25 10:55:29,135 - INFO - Line 195: Found matchup only: NOP@CHI
# 2025-07-25 10:55:29,135 - INFO - Found NOT YET SUBMITTED for team: New Orleans Pelicans
# 2025-07-25 10:55:29,135 - INFO - Found: Lonzo Ball (Chicago Bulls) - Out: DegreeSprain ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness Injury/Illness-LeftKnee;Surgery
# 2025-07-25 10:55:29,136 - INFO - Found: Onuralp Bitim (Chicago Bulls) - Out: DegreeSprain ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness Injury/Illness-General;Illness
# 2025-07-25 10:55:29,136 - INFO - Found: DeMar DeRozan (Chicago Bulls) - Questionable: ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness Injury/Illness-LeftAnkle;Sprain
# 2025-07-25 10:55:29,136 - INFO - Found: Zach LaVine (Chicago Bulls) - Out: ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness Injury/Illness-RightFoot;Soreness
# 2025-07-25 10:55:29,136 - INFO - Found: Justin Lewis (Chicago Bulls) - Out: Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness GLeague-Two-Way
# 2025-07-25 10:55:29,136 - INFO - Found: Adama Sanogo (Chicago Bulls) - Out: DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;Soreness GLeague-Two-Way
# 2025-07-25 10:55:29,136 - INFO - Line 202: Found time+matchup: MEM@PHX at 09:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,137 - INFO - Found NOT YET SUBMITTED for team: Memphis Grizzlies
# 2025-07-25 10:55:29,137 - INFO - Found NOT YET SUBMITTED for team: Phoenix Suns
# 2025-07-25 10:55:29,138 - INFO - Line 206: Found matchup only: OKC@DAL
# 2025-07-25 10:55:29,138 - INFO - Found: Ousmane Dieng (Oklahoma City Thunder) - Out: GLeague-OnAssignment
# 2025-07-25 10:55:29,138 - INFO - Found: Keyontae Johnson (Oklahoma City Thunder) - Out: GLeague-Two-Way
# 2025-07-25 10:55:29,139 - INFO - Found NOT YET SUBMITTED for team: Dallas Mavericks
# 2025-07-25 10:55:29,139 - INFO - Line 209: Found time+matchup: POR@UTA at 09:30(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,139 - INFO - Found: Ibou Badji (Portland Trail Blazers) - Questionable: Injury/Illness-RightThumb; GLeague-Two-Way
# 2025-07-25 10:55:29,140 - INFO - Found: Justin Minaya (Portland Trail Blazers) - Questionable: Injury/Illness-RightThumb; GLeague-Two-Way
# 2025-07-25 10:55:29,140 - INFO - Found: Rayan Rupert (Portland Trail Blazers) - Questionable: Injury/Illness-RightThumb; GLeague-OnAssignment
# 2025-07-25 10:55:29,141 - INFO - Found: Anfernee Simons (Portland Trail Blazers) - Out: Injury/Illness-RightThumb; Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightKnee;Ligament
# 2025-07-25 10:55:29,141 - INFO - Found: Ish Wainright (Portland Trail Blazers) - Out: Injury/Illness-RightThumb; Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightKnee;Ligament Injury/Illness-LeftKnee;MCLSprain
# 2025-07-25 10:55:29,141 - INFO - Found: Robert WilliamsIII (Portland Trail Blazers) - Out: Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightKnee;Ligament Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion
# 2025-07-25 10:55:29,141 - INFO - Found: Josh Christopher (Utah Jazz) - Out: Injury/Illness-RightKnee;Ligament Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion GLeague-Two-Way
# 2025-07-25 10:55:29,142 - INFO - Found: Jordan Clarkson (Utah Jazz) - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Injury/Illness-RightThigh;Contusion
# 2025-07-25 10:55:29,142 - INFO - Found: Kris Dunn (Utah Jazz) - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain PersonalReasons
# 2025-07-25 10:55:29,142 - INFO - Found: Taylor Hendricks (Utah Jazz) - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain GLeague-OnAssignment
# 2025-07-25 10:55:29,142 - INFO - Found: Johnny Juzang (Utah Jazz) - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,142 - INFO - Found: Lauri Markkanen (Utah Jazz) - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain Injury/Illness-LeftHamstring;Strain
# 2025-07-25 10:55:29,142 - INFO - Found: Kelly Olynyk (Utah Jazz) - Questionable: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain Injury/Illness-RightShoulder;Strain
# 2025-07-25 10:55:29,142 - INFO - Found: Micah Potter (Utah Jazz) - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain GLeague-Two-Way
# 2025-07-25 10:55:29,143 - INFO - Found: Brice Sensabaugh (Utah Jazz) - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-RightShoulder;Strain GLeague-OnAssignment
# 2025-07-25 10:55:29,143 - INFO - Line 230: Found time+matchup: DEN@SAC at 10:00(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,143 - INFO - Found NOT YET SUBMITTED for team: Denver Nuggets
# 2025-07-25 10:55:29,143 - INFO - Found: Alex Len (Sacramento Kings) - Out: Injury/Illness-RightHighAnkle; Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation
# 2025-07-25 10:55:29,143 - INFO - Found: Trey Lyles (Sacramento Kings) - Available: Injury/Illness-RightHighAnkle; Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation Injury/Illness-LeftPatellarTendon; -
# 2025-07-25 10:55:29,143 - INFO - Found: Keegan Murray (Sacramento Kings) - Questionable: Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation Injury/Illness-LeftPatellarTendon; Injury/Illness-SiJoint;Irritation
# 2025-07-25 10:55:29,143 - INFO - Line 237: Found time+matchup: HOU@LAL at 10:30(ET) (date: 12/01/2023)
# 2025-07-25 10:55:29,144 - INFO - Found: Victor Oladipo (Houston Rockets) - Out: Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation Injury/Illness-LeftPatellarTendon; Thompson,Amen Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftAdductor;/Hip
# 2025-07-25 10:55:29,144 - INFO - Found: Amen Thompson (Houston Rockets) - Out: Injury/Illness-LeftPatellarTendon; Thompson,Amen Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftAdductor;/Hip Injury/Illness-RightAnkle;Sprain
# 2025-07-25 10:55:29,144 - INFO - Found: Anthony Davis (Los Angeles Lakers) - Probable: Thompson,Amen Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftAdductor;/Hip Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-LeftCalf;Contusion
# 2025-07-25 10:55:29,144 - INFO - Found: Jaxson Hayes (Los Angeles Lakers) - Probable: Injury/Illness-LeftAdductor;/Hip Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-LeftCalf;Contusion Reddish,Cam Probable Injury/Illness-RightGroin;Soreness Vincent,Gabe Out Injury/Illness-LeftKnee;Effusion Injury/Illness-LeftElbow;Soreness
# 2025-07-25 10:55:29,144 - INFO - Found: LeBron James (Los Angeles Lakers) - Questionable: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-LeftCalf;Contusion Reddish,Cam Probable Injury/Illness-RightGroin;Soreness Vincent,Gabe Out Injury/Illness-LeftKnee;Effusion Injury/Illness-LeftCalf;Contusion
# 2025-07-25 10:55:29,144 - INFO - Found: Cam Reddish (Los Angeles Lakers) - Probable: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-LeftCalf;Contusion Reddish,Cam Probable Injury/Illness-RightGroin;Soreness Vincent,Gabe Out Injury/Illness-LeftKnee;Effusion Injury/Illness-RightGroin;Soreness
# 2025-07-25 10:55:29,144 - INFO - Found: Gabe Vincent (Los Angeles Lakers) - Out: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-LeftCalf;Contusion Reddish,Cam Probable Injury/Illness-RightGroin;Soreness Vincent,Gabe Out Injury/Illness-LeftKnee;Effusion Injury/Illness-LeftKnee;Effusion
# 2025-07-25 10:55:29,146 - INFO - Loading from cache: pdf_cache/injury_report_2023-12-03_05PM.pdf
# 2025-07-25 10:55:29,159 - WARNING - 'Rice' NOT found anywhere in the PDF text!
# 2025-07-25 10:55:29,159 - INFO - Line 2: Found full game info: BOS@IND on 12/04/2023 at 07:30(ET)
# 2025-07-25 10:55:29,159 - INFO - Found: Kristaps Porzingis (Boston Celtics) - Out: 12/04/2023 07:30(ET) BOS@IND BostonCeltics Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Injury/Illness-N/A;Upper Injury/Illness-LeftCalf;Strain
# 2025-07-25 10:55:29,160 - INFO - Found: Jordan Walsh (Boston Celtics) - Out: 12/04/2023 07:30(ET) BOS@IND BostonCeltics Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Injury/Illness-N/A;Upper GLeague-OnAssignment
# 2025-07-25 10:55:29,160 - INFO - Found: Kendall Brown (Indiana Pacers) - Questionable: 12/04/2023 07:30(ET) BOS@IND BostonCeltics Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Injury/Illness-N/A;Upper RespiratoryInfection GLeague-Two-Way
# 2025-07-25 10:55:29,160 - INFO - Found: Tyrese Haliburton (Indiana Pacers) - Questionable: Injury/Illness-N/A;Upper RespiratoryInfection Injury/Illness-LeftKnee,Heel;Left Smith,Jalen Out KneeBoneBruise,LeftHeel
# 2025-07-25 10:55:29,160 - INFO - Found: Jalen Smith (Indiana Pacers) - Out: RespiratoryInfection Injury/Illness-LeftKnee,Heel;Left Smith,Jalen Out KneeBoneBruise,LeftHeel Contusion Toppin,Obi Questionable Injury/Illness-LeftAnkle;Sprain KneeBoneBruise,LeftHeel
# 2025-07-25 10:55:29,160 - INFO - Found: Obi Toppin (Indiana Pacers) - Questionable: Injury/Illness-LeftKnee,Heel;Left Smith,Jalen Out KneeBoneBruise,LeftHeel Contusion Toppin,Obi Questionable Injury/Illness-LeftAnkle;Sprain Injury/Illness-LeftAnkle;Sprain
# 2025-07-25 10:55:29,160 - INFO - Found: Oscar Tshiebwe (Indiana Pacers) - Questionable: Smith,Jalen Out KneeBoneBruise,LeftHeel Contusion Toppin,Obi Questionable Injury/Illness-LeftAnkle;Sprain GLeague-Two-Way
# ...
#     - Nathan Knight - Out: Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;S...
#     - Kristaps Porzingis - Out: Springer,Jaden Available Injury/Illness-N/a;Illness Porzingis,Kristaps Out Injury/Illness-LeftCalf;S...
#     - Jordan Walsh - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightH...
#
#   San Antonio Spurs:
#     - Charles Bediako - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightH...
#     - Sidy Cissoko - Out: Porzingis,Kristaps Out Injury/Illness-LeftCalf;Strain Johnson,Keldon Available Injury/Illness-RightH...
#     - Keldon Johnson - Available: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illn...
#     - Doug McDermott - Out: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illn...
#     - Sir'Jabari Rice - Out: Johnson,Keldon Available Injury/Illness-RightHip;Tightness McDermott,Doug Out Injury/Illness-“”;Illn...
#     - Victor Wembanyama - Out: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/...
#
#   New Orleans Pelicans:
#     - Jose Alvarado - Out: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/...
#     - Trey MurphyIII - Available: Wembanyama,Victor Out Injury/Illness-RightHip;Tightness NewOrleansPelicans Alvarado,Jose Out Injury/...
#     - Larry NanceJr. - Out: Injury/Illness-LeftKnee;Partial NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out In...
#     - Matt Ryan - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10...
#     - Dereon Seabron - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10...
#     - NOT YET SUBMITTED - NOT YET SUBMITTED: NOT YET SUBMITTED...
#
#   Denver Nuggets:
#     - Vlatko Cancar - Out: NanceJr.,Larry Out Injury/Illness-RightRib;Fracture Ryan,Matt Out Injury/Illness-RightCalf;Strain 10...
#     - Aaron Gordon - Questionable: Ryan,Matt Out Injury/Illness-RightCalf;Strain 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Inju...
#     - Jay Huff - Out: 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Quest...
#     - Jamal Murray - Questionable: 10:00(ET) DEN@PHX DenverNuggets Cancar,Vlatko Out Injury/Illness-LeftKnee;Surgery Gordon,Aaron Quest...
#     - Jalen Pickett - Out: Gordon,Aaron Questionable Injury/Illness-RightHeel;Strain Murray,Jamal Questionable Injury/Illness-R...
#     - Hunter Tyson - Out: Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Ill...
#     - Peyton Watson - Probable: Murray,Jamal Questionable Injury/Illness-RightAnkle;Sprain Watson,Peyton Probable Injury/Illness-Ill...
#     - NOT YET SUBMITTED - NOT YET SUBMITTED: NOT YET SUBMITTED...
#
#   Phoenix Suns:
#     - Bradley Beal - Out: Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-Lo...
#     - Devin Booker - Out: Watson,Peyton Probable Injury/Illness-Illness;Illness PhoenixSuns Beal,Bradley Out Injury/Illness-Lo...
#     - Damion Lee - Out: PhoenixSuns Beal,Bradley Out Injury/Illness-LowBack;Strain Booker,Devin Out Injury/Illness-RightAnkl...
#     - NOT YET SUBMITTED - NOT YET SUBMITTED: NOT YET SUBMITTED...
#
#   Golden State Warriors:
#     - Usman Garuba - Out: Injury/Illness-RightFinger; Paul,Chris Out Injury/Illness-LeftLowerLegNerve;...
#     - Chris Paul - Out: Injury/Illness-RightFinger; Paul,Chris Out Injury/Illness-LeftLowerLegNerve; Contusion Injury/Illnes...
#     - Gary PaytonII - Out: Contusion PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illne...
#     - Andrew Wiggins - Questionable: Contusion PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illne...
#
#   LA Clippers:
#     - Brandon BostonJr. - Out: PaytonII,Gary Out Injury/Illness-RightCalf;Strain Wiggins,Andrew Questionable Injury/Illness-RightFi...
#     - Mason Plumlee - Out: Injury/Illness-LeftQuadriceps; Plumlee,Mason Out Injury/Illness-LeftMCL;Sprain Injury/Illness-RightA...
#
#   Minnesota Timberwolves:
#     - Jaylen Clark - Out: Plumlee,Mason Out Injury/Illness-LeftMCL;Sprain Injury/Illness-RightAchillesTendon; Edwards,Anthony ...
#     - Anthony Edwards - Doubtful: Injury/Illness-RightAchillesTendon; Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDanie...
#     - Jaden McDaniels - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnk...
#     - Jordan McLaughlin - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnk...
#     - Leonard Miller - Out: Edwards,Anthony Doubtful Injury/Illness-RightHip;Pointer McDaniels,Jaden Out Injury/Illness-RightAnk...
#
#   Charlotte Hornets:
#     - Amari Bailey - Out: McDaniels,Jaden Out Injury/Illness-RightAnkle;Sprain McLaughlin,Jordan Out Injury/Illness-RightKneeM...
#     - LaMelo Ball - Out: McLaughlin,Jordan Out Injury/Illness-RightKneeMcl;Sprain Ball,LaMelo Out Injury/Illness-RightAnkle;S...
#     - Cody Martin - Out: Ball,LaMelo Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury Miller,Brandon Quest...
#     - Brandon Miller - Questionable: Injury/Illness-LeftKnee;Injury Miller,Brandon Questionable Injury/Illness-LeftAnkle;Sprain Injury/Il...
#     - Frank Ntilikina - Out: Miller,Brandon Questionable Injury/Illness-LeftAnkle;Sprain Injury/Illness-LeftTibia;Non- displacedf...
#     - Nick Richards - Questionable: Injury/Illness-LeftTibia;Non- displacedfracture ConcussionProtocol...
#
#   Cleveland Cavaliers:
#     - Emoni Bates - Out: displacedfracture Jerome,Ty Out Injury/Illness-RightAnkle;Sprain GLeague-Two-Way...
#     - Ty Jerome - Out: Jerome,Ty Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury Injury/Illness-RightAn...
#     - Caris LeVert - Out: Jerome,Ty Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftKnee;Injury...
#     - Isaiah Mobley - Out: Injury/Illness-LeftKnee;Injury Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdano...
#     - Ricky Rubio - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illne...
#     - Dean Wade - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illne...
#
#   Detroit Pistons:
#     - Bojan Bogdanovic - Probable: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illne...
#     - Malcolm Cazalon - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illne...
#     - Joe Harris - Out: Wade,Dean Out Injury/Illness-RightAnkle;Sprain DetroitPistons Bogdanovic,Bojan Probable Injury/Illne...
#     - Monte Morris - Out: Harris,Joe Out Injury/Illness-RightShoulder;Sprain Injury/Illness-RightQuadriceps; Strain Thompson,A...
#     - Jared Rhoden - Out: Injury/Illness-RightQuadriceps; Strain Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture G...
#     - Ausar Thompson - Probable: Strain Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture Injury/Illness-RightShoulder; Inj...
#
#   Brooklyn Nets:
#     - Armoni Brooks - Out: Thompson,Ausar Probable Injury/Illness-RightFacial;Fracture Injury/Illness-RightShoulder; GLeague-Tw...
#     - Noah Clowney - Out: Injury/Illness-RightShoulder; Injury/Illness-LeftLowerBack;...
#     - Keon Johnson - Out: Injury/Illness-RightShoulder; Injury/Illness-LeftLowerBack; GLeague-Two-Way...
#     - Ben Simmons - Out: Injury/Illness-LeftLowerBack; SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain...
#     - Dennis SmithJr. - Probable: Injury/Illness-LeftLowerBack; SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain WalkerIV,Lonn...
#     - Lonnie WalkerIV - Out: SmithJr.,Dennis Probable Injury/Illness-LowerBack;Strain WalkerIV,Lonnie Out Injury/Illness-LeftHams...
#     - Dariq Whitehead - Out: WalkerIV,Lonnie Out Injury/Illness-LeftHamstring;Strain Injury/Illness-RightFoot;Injury 08:00(ET) AT...
#     - Jalen Wilson - Out: Injury/Illness-RightFoot;Injury 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftTh...
#
#   Atlanta Hawks:
#     - Kobe Bufkin - Out: 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture Injury/Illness-Righ...
#     - Mouhamed Gueye - Out: 08:00(ET) ATL@MIL AtlantaHawks Bufkin,Kobe Out Injury/Illness-LeftThunb;Fracture Injury/Illness-Righ...
#     - Jalen Johnson - Out: Fracture Injury/Illness-LeftDistalRadius; Fracture...
#     - Seth Lundy - Out: Injury/Illness-LeftDistalRadius; Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain GLeag...
#     - Miles Norris - Out: Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdd...
#
#   Milwaukee Bucks:
#     - Marques Bolden - Available: Fracture Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdd...
#     - Pat Connaughton - Out: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Sur...
#     - Jae Crowder - Out: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Sur...
#     - Andre JacksonJr. - Questionable: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Sur...
#     - TyTy WashingtonJr. - Available: Connaughton,Pat Out Injury/Illness-RightAnkle;Sprain Crowder,Jae Out Injury/Illness-LeftAdductor;Sur...
#     - Lindell Wigginton - Available: Crowder,Jae Out Injury/Illness-LeftAdductor;Surgery JacksonJr.,Andre Questionable Injury/Illness-Low...
#
#   Indiana Pacers:
#     - Kendall Brown - Questionable: JacksonJr.,Andre Questionable Injury/Illness-LowerBack;Spasms Haliburton,Tyrese Questionable Injury/...
#     - Tyrese Haliburton - Questionable: Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left Kne...
#     - Jalen Smith - Out: Haliburton,Tyrese Questionable Injury/Illness-RightKnee;Bruise Injury/Illness-LeftKnee,Heel;Left Kne...
#     - Oscar Tshiebwe - Questionable: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Il...
#     - Isaiah Wong - Questionable: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Il...
#
#   Miami Heat:
#     - Bam Adebayo - Out: Contusion MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Il...
#     - Jimmy Butler - Probable: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-Righ...
#     - R.J. Hampton - Out: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-Righ...
#     - Tyler Herro - Out: MiamiHeat Adebayo,Bam Out Injury/Illness-LeftHip;Contusion Butler,Jimmy Probable Injury/Illness-Righ...
#     - Haywood Highsmith - Available: Butler,Jimmy Probable Injury/Illness-RightAnkle;Sprain Hampton,R.J. Out Injury/Illness-RightKnee;Spr...
#     - Duncan Robinson - Available: Hampton,R.J. Out Injury/Illness-RightKnee;Sprain Herro,Tyler Out Injury/Illness-RightAnkle;Sprain Hi...
#     - Dru Smith - Out: Highsmith,Haywood Available Injury/Illness-LowerBack;Contusion Robinson,Duncan Available Injury/Illn...
#
#   Chicago Bulls:
#     - Lonzo Ball - Out: DegreeSprain ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Il...
#     - Onuralp Bitim - Out: DegreeSprain ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Il...
#     - DeMar DeRozan - Questionable: ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General...
#     - Zach LaVine - Out: ChicagoBulls Ball,Lonzo Out Injury/Illness-LeftKnee;Surgery Bitim,Onuralp Out Injury/Illness-General...
#     - Justin Lewis - Out: Bitim,Onuralp Out Injury/Illness-General;Illness DeRozan,DeMar Questionable Injury/Illness-LeftAnkle...
#     - Adama Sanogo - Out: DeRozan,DeMar Questionable Injury/Illness-LeftAnkle;Sprain LaVine,Zach Out Injury/Illness-RightFoot;...
#
#   Oklahoma City Thunder:
#     - Ousmane Dieng - Out: GLeague-OnAssignment...
#     - Keyontae Johnson - Out: GLeague-Two-Way...
#
#   Portland Trail Blazers:
#     - Ibou Badji - Questionable: Injury/Illness-RightThumb; GLeague-Two-Way...
#     - Justin Minaya - Questionable: Injury/Illness-RightThumb; GLeague-Two-Way...
#     - Rayan Rupert - Questionable: Injury/Illness-RightThumb; GLeague-OnAssignment...
#     - Anfernee Simons - Out: Injury/Illness-RightThumb; Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightK...
#     - Ish Wainright - Out: Injury/Illness-RightThumb; Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightK...
#     - Robert WilliamsIII - Out: Wainright,Ish Out Injury/Illness-LeftKnee;MCLSprain Injury/Illness-RightKnee;Ligament Clarkson,Jorda...
#
#   Utah Jazz:
#     - Josh Christopher - Out: Injury/Illness-RightKnee;Ligament Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion GLeague-Tw...
#     - Jordan Clarkson - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Injury/Illness-RightThigh;Contusion...
#     - Kris Dunn - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamst...
#     - Taylor Hendricks - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamst...
#     - Johnny Juzang - Out: Clarkson,Jordan Out Injury/Illness-RightThigh;Contusion Markkanen,Lauri Out Injury/Illness-LeftHamst...
#     - Lauri Markkanen - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-Rig...
#     - Kelly Olynyk - Questionable: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-Rig...
#     - Micah Potter - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-Rig...
#     - Brice Sensabaugh - Out: Markkanen,Lauri Out Injury/Illness-LeftHamstring;Strain Olynyk,Kelly Questionable Injury/Illness-Rig...
#
#   Sacramento Kings:
#     - Alex Len - Out: Injury/Illness-RightHighAnkle; Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation...
#     - Trey Lyles - Available: Injury/Illness-RightHighAnkle; Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation I...
#     - Keegan Murray - Questionable: Sprain Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation Injury/Illness-LeftPatellarTendo...
#
#   Houston Rockets:
#     - Victor Oladipo - Out: Murray,Keegan Questionable Injury/Illness-SiJoint;Irritation Injury/Illness-LeftPatellarTendon; Thom...
#     - Amen Thompson - Out: Injury/Illness-LeftPatellarTendon; Thompson,Amen Out Injury/Illness-RightAnkle;Sprain Injury/Illness...
#
#   Los Angeles Lakers:
#     - Anthony Davis - Probable: Thompson,Amen Out Injury/Illness-RightAnkle;Sprain Injury/Illness-LeftAdductor;/Hip Hayes,Jaxson Pro...
#     - Jaxson Hayes - Probable: Injury/Illness-LeftAdductor;/Hip Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBro...
#     - LeBron James - Questionable: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-Lef...
#     - Cam Reddish - Probable: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-Lef...
#     - Gabe Vincent - Out: Hayes,Jaxson Probable Injury/Illness-LeftElbow;Soreness James,LeBron Questionable Injury/Illness-Lef...
#
# ==================================================
# === Testing 2023-12-03 05PM (original) ===
#
# Game: Multiple Multiple
# Injuries found: 10
# Players: Kristaps Porzingis, Jordan Walsh, Kendall Brown, Tyrese Haliburton, Jalen Smith, Obi Toppin, Oscar Tshiebwe, Isaiah Wong, NOT YET SUBMITTED, NOT YET SUBMITTED
#
# Exported 176 total injuries to CSV
